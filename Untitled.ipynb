# %%
import numpy as np
import pandas as pd

# %%
inp=pd.read_csv('input.txt')

# %%
list1=[]

for i in inp['1000000']:
    list1.append(i)

# %%
list1
# Out:
# [5,
#  8,
#  6,
#  3,
#  5,
#  9,
#  7,
#  9,
#  9,
#  2,
#  1,
#  9,
#  7,
#  9,
#  1,
#  3,
#  8,
#  8,
#  8,
#  2,
#  7,
#  2,
#  1,
#  3,
#  5,
#  7,
#  7,
#  1,
#  9,
#  8,
#  8,
#  3,
#  6,
#  2,
#  9,
#  1,
#  2,
#  2,
#  1,
#  4,
#  2,
#  3,
#  2,
#  1,
#  3,
#  3,
#  3,
#  5,
#  7,
#  5,
#  9,
#  3,
#  8,
#  2,
#  2,
#  6,
#  4,
#  9,
#  4,
#  5,
#  8,
#  8,
#  1,
#  9,
#  9,
#  2,
#  1,
#  1,
#  7,
#  8,
#  5,
#  8,
#  8,
#  8,
#  7,
#  5,
#  6,
#  1,
#  6,
#  3,
#  7,
#  8,
#  1,
#  5,
#  3,
#  6,
#  7,
#  9,
#  1,
#  7,
#  4,
#  9,
#  6,
#  8,
#  7,
#  9,
#  8,
#  7,
#  3,
#  1,
#  4,
#  1,
#  3,
#  6,
#  3,
#  9,
#  2,
#  1,
#  4,
#  4,
#  6,
#  3,
#  6,
#  7,
#  4,
#  6,
#  8,
#  8,
#  9,
#  9,
#  1,
#  2,
#  7,
#  2,
#  8,
#  1,
#  6,
#  8,
#  2,
#  7,
#  8,
#  8,
#  5,
#  2,
#  2,
#  1,
#  1,
#  8,
#  7,
#  3,
#  9,
#  7,
#  6,
#  7,
#  2,
#  3,
#  6,
#  5,
#  9,
#  8,
#  9,
#  2,
#  7,
#  4,
#  4,
#  3,
#  8,
#  6,
#  2,
#  7,
#  1,
#  3,
#  3,
#  9,
#  1,
#  2,
# ...

# %% [markdown]
# ## n -> the total number of monkeys killed
# ## summ -> ensuring less than 1000 health loss
# ## product -> ensuring less than 1000000 injury
# ## count_list -> array of n values generated

# %%
count_list=[]
for j in list1:
    n=0
    summ=0
    product=1    
    for i in  list1:
        if summ<1000 and product<1000000:
            summ=summ+i
            product=product*i
            n=n+1
    count_list.append(n)

# %%
max_monkeys_killed=max(count_list)
print max_monkeys_killed

# %% [markdown]
# # FINALLY MAX_MONKEYS_KILLED GIVES THE MAXIMUM NUMBER OF MONKEYS THAT CAN BE KILLED MEETING HEALTH AND INJURY CONDITIONS
#
#
# # SORRY I COULD NOT GENERATE THE ANSWER AS MY LAPTOP MACHINE SPECIFICATIONS COULD NOT GENERATE THE ANSWER OF COUNT_LIST IN TIME
